# %%
import matplotlib.pyplot as plt
import datetime
import pandas as pd
import numpy as np
import seaborn as sns
from tqdm import tqdm

# %%
sales_data = pd.read_csv('sales_data_long.csv')
weather_seasonality = pd.read_csv('weather_seasonality.csv')

# %%
#sales_data['Date'] = pd.to_datetime(sales_data['Date'])
weather_seasonality['Date'] = weather_seasonality['date'] 
sales_data['store_id'] = sales_data['store_id'].astype(str).str.replace(',', '').astype(int)

# %%
# stores = [14]
# sales_data = sales_data[sales_data['store_id'].isin(stores)]

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19014 entries, 0 to 19013
# Data columns (total 18 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   store_id                           19014 non-null  int32
#  1   Date                               19014 non-null  object
#  2   Total_Sales                        19014 non-null  float64
#  3   Free Delivery_Require Purchase     8968 non-null   object
#  4   Free Delivery_Product              8968 non-null   object
#  5   Free Delivery_Promo_Active         19014 non-null  int64
#  6   Overall Discount_Require Purchase  1222 non-null   object
#  7   Overall Discount_Product           1222 non-null   object
#  8   Overall Discount_Promo_Active      19014 non-null  int64
#  9   Product Discount_Require Purchase  2450 non-null   object
#  10  Product Discount_Product           2450 non-null   object
# ...

# %%
weather_seasonality.info()
#weather_seasonality = weather_seasonality[pd.to_datetime(weather_seasonality['date']) < pd.to_datetime(sales_data['Date']).max()].reset_index(drop=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50985 entries, 0 to 50984
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   station             50985 non-null  object
#  1   date                50985 non-null  object
#  2   PRCP                50964 non-null  float64
#  3   SNOW                50189 non-null  float64
#  4   TMAX                50938 non-null  float64
#  5   TMIN                50937 non-null  float64
#  6   Store               50985 non-null  object
#  7   City                50985 non-null  object
#  8   Is College          50985 non-null  int64
#  9   Number              50985 non-null  int64
#  10  id                  50985 non-null  int64
#  11  Date                50985 non-null  object
#  12  Annual_Seasonality  47210 non-null  float64
#  13  Weekly_Seasonality  47210 non-null  float64
#  14  Store_ID            47210 non-null  float64
# ...

# %%
data =  (sales_data).merge(weather_seasonality, how='left', left_on=['store_id','Date'], right_on=['id','Date'])

# %%
data.head()
# Out:
#    store_id        Date  Total_Sales Free Delivery_Require Purchase  \
# 0        14  2024-02-22      1397.62                            Yes
# 1        14  2024-02-22      1397.62                            Yes
# 2        14  2024-02-23      1720.61                            Yes
# 3        14  2024-02-23      1720.61                            Yes
# 4        14  2024-02-24       924.01                            Yes
#
#   Free Delivery_Product  Free Delivery_Promo_Active  \
# 0         Free Delivery                           1
# 1         Free Delivery                           1
# 2         Free Delivery                           1
# 3         Free Delivery                           1
# 4         Free Delivery                           1
#
#   Overall Discount_Require Purchase Overall Discount_Product  \
# 0                                No                      All
# 1                                No                      All
# ...
